# %%
# setup
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, r2_score, mean_squared_error

# %%
pd.options.display.max_columns = None

# %%
data = pd.read_csv('fifa21_train.csv')
print(data.shape)
data.drop_duplicates()
data.dropna(axis = 0, how = 'all', inplace = True)
data.rename(columns=str.upper, inplace=True)
data.rename(columns=lambda x: x.strip().replace(" ", "_"), inplace=True)
print(data.shape)
data.head()
# Out:
# (11701, 101)
# (11701, 101)
#        ID           NAME  AGE  NATIONALITY                        CLUB   BP  \
# 0  184383      A. Pasche   26  Switzerland           FC Lausanne-Sport   CM
# 1  188044  Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC   ST
# 2  184431    S. Giovinco   33        Italy                    Al Hilal  CAM
# 3  233796       J. Evans   22        Wales                Swansea City  CDM
# 4  234799     Y. Demoncy   23       France  US Orléans Loiret Football  CDM
#
#    POSITION                               TEAM_&_CONTRACT HEIGHT  WEIGHT  \
# 0    CM CDM                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs
# 1  ST LW LM  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs
# 2    CAM CF                          Al Hilal 2019 ~ 2022   5'4"  134lbs
# 3    CDM CM                      Swansea City 2016 ~ 2021  5'10"  152lbs
# 4    CDM CM        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs
#
# ...

# %%
print(data.columns.tolist())
data.info()
# Out:
# ['ID', 'NAME', 'AGE', 'NATIONALITY', 'CLUB', 'BP', 'POSITION', 'TEAM_&_CONTRACT', 'HEIGHT', 'WEIGHT', 'FOOT', 'GROWTH', 'JOINED', 'LOAN_DATE_END', 'VALUE', 'WAGE', 'RELEASE_CLAUSE', 'CONTRACT', 'ATTACKING', 'CROSSING', 'FINISHING', 'HEADING_ACCURACY', 'SHORT_PASSING', 'VOLLEYS', 'SKILL', 'DRIBBLING', 'CURVE', 'FK_ACCURACY', 'LONG_PASSING', 'BALL_CONTROL', 'MOVEMENT', 'ACCELERATION', 'SPRINT_SPEED', 'AGILITY', 'REACTIONS', 'BALANCE', 'POWER', 'SHOT_POWER', 'JUMPING', 'STAMINA', 'STRENGTH', 'LONG_SHOTS', 'MENTALITY', 'AGGRESSION', 'INTERCEPTIONS', 'POSITIONING', 'VISION', 'PENALTIES', 'COMPOSURE', 'DEFENDING', 'MARKING', 'STANDING_TACKLE', 'SLIDING_TACKLE', 'GOALKEEPING', 'GK_DIVING', 'GK_HANDLING', 'GK_KICKING', 'GK_POSITIONING', 'GK_REFLEXES', 'TOTAL_STATS', 'BASE_STATS', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'HITS', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RW
# ...

# %%
data.dtypes.head(20)
# Out:
# ID                  int64
# NAME               object
# AGE                 int64
# NATIONALITY        object
# CLUB               object
# BP                 object
# POSITION           object
# TEAM_&_CONTRACT    object
# HEIGHT             object
# WEIGHT             object
# FOOT               object
# GROWTH              int64
# JOINED             object
# LOAN_DATE_END      object
# VALUE              object
# WAGE               object
# RELEASE_CLAUSE     object
# CONTRACT           object
# ATTACKING           int64
# CROSSING            int64
# dtype: object

# %%
data.drop(columns=['ID','NAME', 'LOAN_DATE_END', 'CONTRACT'],inplace=True)
data.head()
# Out:
#    AGE  NATIONALITY                        CLUB   BP  POSITION  \
# 0   26  Switzerland           FC Lausanne-Sport   CM    CM CDM
# 1   30     China PR     Beijing Sinobo Guoan FC   ST  ST LW LM
# 2   33        Italy                    Al Hilal  CAM    CAM CF
# 3   22        Wales                Swansea City  CDM    CDM CM
# 4   23       France  US Orléans Loiret Football  CDM    CDM CM
#
#                                 TEAM_&_CONTRACT HEIGHT  WEIGHT   FOOT  GROWTH  \
# 0                 FC Lausanne-Sport 2015 ~ 2020   5'9"  161lbs  Right       1
# 1  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  159lbs  Right       0
# 2                          Al Hilal 2019 ~ 2022   5'4"  134lbs  Right       0
# 3                      Swansea City 2016 ~ 2021  5'10"  152lbs  Right      13
# 4        US Orléans Loiret Football 2018 ~ 2021  5'11"  150lbs  Right       8
#
#          JOINED  VALUE  WAGE RELEASE_CLAUSE  ATTACKING  CROSSING  FINISHING  \
# ...

# %%
print(data.isna().sum()[data.isna().sum() != 0])
# Out:
# CLUB               18
# POSITION          288
# JOINED             41
# VOLLEYS            41
# CURVE              41
# AGILITY            41
# BALANCE            41
# JUMPING            41
# INTERCEPTIONS       7
# POSITIONING         7
# VISION             41
# COMPOSURE         279
# SLIDING_TACKLE     41
# A/W                59
# D/W                59
# dtype: int64

# %%
print(data['POSITION'].isna().sum())
print(data['POSITION'].nunique())
data.dropna(subset=['POSITION'], inplace=True)
print(data['POSITION'].isna().sum())
# Out:
# 288
# 543
# 0

# %%
    
# sorts positions string asc
def sort_positions(pos):
    pos = pos.split()
    pos.sort()
    return ' '.join(pos)

data['POSITION'] = data['POSITION'].apply(lambda x: sort_positions(x))
# print(data['POSITION'].nunique())
# print(data['POSITION'].unique())

# %%
# # retrieve data from TEAM_&_CONTRACT column
# years_ended = r'(\d{4}) ~ (\d{4})'
# years_continued = r'(\d{4})(?!\d|,|$)'
# date_info_e = data['TEAM_&_CONTRACT'].str.extract(years_ended)
# date_info_c = data['TEAM_&_CONTRACT'].str.extract(years_continued)
# date_info = date_info_e.combine_first(date_info_c)
# ## if secont place empty, then on loan -- continues
# date_info[1].fillna(9999, inplace=True)
# # create new column, assign values
# data['CONTRACT_START'] = date_info[0]
# data['CONTRACT_END'] = date_info[1]
# data.drop(columns=['TEAM_&_CONTRACT'],inplace=True)

# data.head()

# %%
def get_contract_terms(data):
    years_ended = r'(\d{4}) ~ (\d{4})'
    years_continued = r'(\d{4})(?!\d|,|$)'
    date_info_e = data['TEAM_&_CONTRACT'].str.extract(years_ended)
    date_info_c = data['TEAM_&_CONTRACT'].str.extract(years_continued)
    date_info = date_info_e.combine_first(date_info_c)
    ## if secont place empty, then on loan -- continues
    date_info[1].fillna(9999, inplace=True)
    # create new column, assign values
    data['CONTRACT_START'] = date_info[0]
    data['CONTRACT_END'] = date_info[1]
    data.drop(columns=['TEAM_&_CONTRACT'],inplace=True)
    
    return data

# %%
get_contract_terms(data)
data
# Out:
#        AGE  NATIONALITY                        CLUB   BP   POSITION HEIGHT  \
# 0       26  Switzerland           FC Lausanne-Sport   CM     CDM CM   5'9"
# 1       30     China PR     Beijing Sinobo Guoan FC   ST   LM LW ST   6'0"
# 2       33        Italy                    Al Hilal  CAM     CAM CF   5'4"
# 3       22        Wales                Swansea City  CDM     CDM CM  5'10"
# 4       23       France  US Orléans Loiret Football  CDM     CDM CM  5'11"
# ...    ...          ...                         ...  ...        ...    ...
# 11695   29         Peru                  Melgar FBC   ST         ST   5'7"
# 11696   25      Iceland       Jagiellonia Białystok   LB         LB   6'1"
# 11697   27       France                ESTAC Troyes   GK         GK   6'1"
# 11698   22        Chile              CD Antofagasta   RM  CAM LM RM   5'6"
# 11700   22    Argentina            Portland Timbers  CAM  CAM LM ST   5'7"
#
# ...

# %%
def convert_weight(data):
    foot = data['HEIGHT'].str.split("'").str[0]
    inches = data['HEIGHT'].str.split("'").str[1].str.split('"').str[0]
    height = foot + '.' + inches
    data['HEIGHT'] = height
    data['HEIGHT'] = pd.to_numeric(data['HEIGHT'], errors='coerce')
    return data

# %%
convert_weight(data)
data.head()
# Out:
#    AGE  NATIONALITY                        CLUB   BP  POSITION  HEIGHT  \
# 0   26  Switzerland           FC Lausanne-Sport   CM    CDM CM    5.90
# 1   30     China PR     Beijing Sinobo Guoan FC   ST  LM LW ST    6.00
# 2   33        Italy                    Al Hilal  CAM    CAM CF    5.40
# 3   22        Wales                Swansea City  CDM    CDM CM    5.10
# 4   23       France  US Orléans Loiret Football  CDM    CDM CM    5.11
#
#    WEIGHT   FOOT  GROWTH        JOINED  VALUE  WAGE RELEASE_CLAUSE  ATTACKING  \
# 0  161lbs  Right       1   Jul 1, 2015  €525K   €4K          €801K        258
# 1  159lbs  Right       0  Jan 16, 2015  €8.5M  €23K             €0        365
# 2  134lbs  Right       0  Jan 31, 2019    €9M  €49K         €15.3M        336
# 3  152lbs  Right      13   Jul 1, 2016  €275K   €4K          €694K        242
# 4  150lbs  Right       8   Jul 1, 2018  €725K   €2K          €1.4M        249
#
# ...

# %%
print(data.isna().sum()[data.isna().sum() != 0])
# Out:
# CLUB               15
# JOINED             27
# VOLLEYS            27
# CURVE              27
# AGILITY            27
# BALANCE            27
# JUMPING            27
# INTERCEPTIONS       4
# POSITIONING         4
# VISION             27
# COMPOSURE         191
# SLIDING_TACKLE     27
# A/W                37
# D/W                37
# CONTRACT_START    262
# dtype: int64

# %%
def convert_weight(data):
    data['WEIGHT'] = data['WEIGHT'].str.split("l").str[0]
    data['WEIGHT'] = pd.to_numeric(data['WEIGHT'], errors='coerce')
    return data

# %%
convert_weight(data)
data['WEIGHT'].dtype
# Out:
# dtype('int64')

# %%
data.head()
# Out:
#    AGE  NATIONALITY                        CLUB   BP  POSITION  HEIGHT  \
# 0   26  Switzerland           FC Lausanne-Sport   CM    CDM CM    5.90
# 1   30     China PR     Beijing Sinobo Guoan FC   ST  LM LW ST    6.00
# 2   33        Italy                    Al Hilal  CAM    CAM CF    5.40
# 3   22        Wales                Swansea City  CDM    CDM CM    5.10
# 4   23       France  US Orléans Loiret Football  CDM    CDM CM    5.11
#
#    WEIGHT   FOOT  GROWTH        JOINED  VALUE  WAGE RELEASE_CLAUSE  ATTACKING  \
# 0     161  Right       1   Jul 1, 2015  €525K   €4K          €801K        258
# 1     159  Right       0  Jan 16, 2015  €8.5M  €23K             €0        365
# 2     134  Right       0  Jan 31, 2019    €9M  €49K         €15.3M        336
# 3     152  Right      13   Jul 1, 2016  €275K   €4K          €694K        242
# 4     150  Right       8   Jul 1, 2018  €725K   €2K          €1.4M        249
#
# ...

# %%
data['RWB'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0        59+1
# 1        57+2
# 2        59+2
# 3        56+2
# 4        64+2
#          ...
# 11695    46+2
# 11696    63+2
# 11697    25+2
# 11698    49+2
# 11700    46+2
# Name: RWB, Length: 11413, dtype: object>

# %%
def strip_potential(data):
    columns = ['LS','ST','RS','LW','LF','CF','RF','RW','LAM','CAM','RAM','LM','LCM','CM','RCM','RM','LWB','LDM','CDM','RDM','RWB','LB','LCB','CB','RCB','RB','GK']
    for colum in columns:
        data[colum] = data[colum].str.split("+").str[0]
        data[colum] = pd.to_numeric(data[colum], errors='coerce')
    return data

# %%
strip_potential(data)
# Out:
#        AGE  NATIONALITY                        CLUB   BP   POSITION  HEIGHT  \
# 0       26  Switzerland           FC Lausanne-Sport   CM     CDM CM    5.90
# 1       30     China PR     Beijing Sinobo Guoan FC   ST   LM LW ST    6.00
# 2       33        Italy                    Al Hilal  CAM     CAM CF    5.40
# 3       22        Wales                Swansea City  CDM     CDM CM    5.10
# 4       23       France  US Orléans Loiret Football  CDM     CDM CM    5.11
# ...    ...          ...                         ...  ...        ...     ...
# 11695   29         Peru                  Melgar FBC   ST         ST    5.70
# 11696   25      Iceland       Jagiellonia Białystok   LB         LB    6.10
# 11697   27       France                ESTAC Troyes   GK         GK    6.10
# 11698   22        Chile              CD Antofagasta   RM  CAM LM RM    5.60
# 11700   22    Argentina            Portland Timbers  CAM  CAM LM ST    5.70
#
# ...

# %%
def convert_monetary_columns_to_m(data):
    columns = ['VALUE', 'WAGE', 'RELEASE_CLAUSE']
    for column in columns:
        data[column] = data[column].str.replace('€', '').str.replace('M', '').str.replace('K', ' / 1000').map(pd.eval).astype(float)
    return data

# %%
convert_monetary_columns_to_m(data)
# Out:
#        AGE  NATIONALITY                        CLUB   BP   POSITION  HEIGHT  \
# 0       26  Switzerland           FC Lausanne-Sport   CM     CDM CM    5.90
# 1       30     China PR     Beijing Sinobo Guoan FC   ST   LM LW ST    6.00
# 2       33        Italy                    Al Hilal  CAM     CAM CF    5.40
# 3       22        Wales                Swansea City  CDM     CDM CM    5.10
# 4       23       France  US Orléans Loiret Football  CDM     CDM CM    5.11
# ...    ...          ...                         ...  ...        ...     ...
# 11695   29         Peru                  Melgar FBC   ST         ST    5.70
# 11696   25      Iceland       Jagiellonia Białystok   LB         LB    6.10
# 11697   27       France                ESTAC Troyes   GK         GK    6.10
# 11698   22        Chile              CD Antofagasta   RM  CAM LM RM    5.60
# 11700   22    Argentina            Portland Timbers  CAM  CAM LM ST    5.70
#
# ...

# %%
data['VALUE'].dtype
# Out:
# dtype('float64')

# %%
data.head()
# Out:
#    AGE  NATIONALITY                        CLUB   BP  POSITION  HEIGHT  \
# 0   26  Switzerland           FC Lausanne-Sport   CM    CDM CM    5.90
# 1   30     China PR     Beijing Sinobo Guoan FC   ST  LM LW ST    6.00
# 2   33        Italy                    Al Hilal  CAM    CAM CF    5.40
# 3   22        Wales                Swansea City  CDM    CDM CM    5.10
# 4   23       France  US Orléans Loiret Football  CDM    CDM CM    5.11
#
#    WEIGHT   FOOT  GROWTH        JOINED  VALUE   WAGE  RELEASE_CLAUSE  \
# 0     161  Right       1   Jul 1, 2015  0.525  0.004           0.801
# 1     159  Right       0  Jan 16, 2015  8.500  0.023           0.000
# 2     134  Right       0  Jan 31, 2019  9.000  0.049          15.300
# 3     152  Right      13   Jul 1, 2016  0.275  0.004           0.694
# 4     150  Right       8   Jul 1, 2018  0.725  0.002           1.400
#
#    ATTACKING  CROSSING  FINISHING  HEADING_ACCURACY  SHORT_PASSING  VOLLEYS  \
# ...

# %%
print(data.isna().sum()[data.isna().sum() != 0])
# Out:
# CLUB               15
# JOINED             27
# VOLLEYS            27
# CURVE              27
# AGILITY            27
# BALANCE            27
# JUMPING            27
# INTERCEPTIONS       4
# POSITIONING         4
# VISION             27
# COMPOSURE         191
# SLIDING_TACKLE     27
# A/W                37
# D/W                37
# CONTRACT_START    262
# dtype: int64

# %%
data[['VALUE', 'WAGE', 'RELEASE_CLAUSE']]
# Out:
#        VALUE     WAGE  RELEASE_CLAUSE
# 0      0.525    0.004           0.801
# 1      8.500    0.023           0.000
# 2      9.000    0.049          15.300
# 3      0.275    0.004           0.694
# 4      0.725    0.002           1.400
# ...      ...      ...             ...
# 11695  0.550  500.000           1.200
# 11696  0.625    0.003           0.891
# 11697  1.600    0.004           2.900
# 11698  1.100    0.002           1.700
# 11700  0.700    0.002           1.200
#
# [11413 rows x 3 columns]

# %%
data.head(10)
# Out:
#    AGE         NATIONALITY                           CLUB   BP  POSITION  \
# 0   26         Switzerland              FC Lausanne-Sport   CM    CDM CM
# 1   30            China PR        Beijing Sinobo Guoan FC   ST  LM LW ST
# 2   33               Italy                       Al Hilal  CAM    CAM CF
# 3   22               Wales                   Swansea City  CDM    CDM CM
# 4   23              France     US Orléans Loiret Football  CDM    CDM CM
# 5   33            China PR  Shanghai Greenland Shenhua FC   LM  LM LW RW
# 6   30               Italy                          Parma   RB     LB RB
# 7   22               Italy                       AC Monza   LM       CAM
# 8   34  Bosnia Herzegovina                      FC Lugano   CB    CB CDM
# 9   35           Argentina          Club Atlético Huracán   CB     CB LB
#
#    HEIGHT  WEIGHT   FOOT  GROWTH        JOINED  VALUE     WAGE  \
# 0    5.90     161  Right       1   Jul 1, 2015  0.525    0.004
# ...

# %%
data[['W/F','SM','IR']].dtypes
# Out:
# W/F    object
# SM     object
# IR     object
# dtype: object

# %%
def remove_symbol(data):
    columns = ['W/F', 'SM', 'IR']
    for column in columns:
        data[column] = data[column].str.extract(r'(\d+)').astype(float).fillna(0).astype(int)
    return data

# %%
remove_symbol(data)
# Out:
#        AGE  NATIONALITY                        CLUB   BP   POSITION  HEIGHT  \
# 0       26  Switzerland           FC Lausanne-Sport   CM     CDM CM    5.90
# 1       30     China PR     Beijing Sinobo Guoan FC   ST   LM LW ST    6.00
# 2       33        Italy                    Al Hilal  CAM     CAM CF    5.40
# 3       22        Wales                Swansea City  CDM     CDM CM    5.10
# 4       23       France  US Orléans Loiret Football  CDM     CDM CM    5.11
# ...    ...          ...                         ...  ...        ...     ...
# 11695   29         Peru                  Melgar FBC   ST         ST    5.70
# 11696   25      Iceland       Jagiellonia Białystok   LB         LB    6.10
# 11697   27       France                ESTAC Troyes   GK         GK    6.10
# 11698   22        Chile              CD Antofagasta   RM  CAM LM RM    5.60
# 11700   22    Argentina            Portland Timbers  CAM  CAM LM ST    5.70
#
# ...

# %%
print(data.isna().sum()[data.isna().sum() != 0])
# Out:
# CLUB               15
# JOINED             27
# VOLLEYS            27
# CURVE              27
# AGILITY            27
# BALANCE            27
# JUMPING            27
# INTERCEPTIONS       4
# POSITIONING         4
# VISION             27
# COMPOSURE         191
# SLIDING_TACKLE     27
# A/W                37
# D/W                37
# CONTRACT_START    262
# dtype: int64

# %%
data['JOINED']
# Out:
# 0         Jul 1, 2015
# 1        Jan 16, 2015
# 2        Jan 31, 2019
# 3         Jul 1, 2016
# 4         Jul 1, 2018
#              ...
# 11695     Jul 1, 2019
# 11696     Feb 8, 2018
# 11697     Jul 1, 2019
# 11698    Jan 23, 2019
# 11700    Jul 22, 2019
# Name: JOINED, Length: 11413, dtype: object
